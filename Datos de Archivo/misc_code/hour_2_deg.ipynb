# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

c = SkyCoord("01 20 51.4586151266 +66 04 20.241816401", unit=(u.hourangle, u.deg))

ra_deg = c.ra.deg
dec_deg = c.dec.deg

print(ra_deg, dec_deg)
# Out:
# 20.214410896360828 66.07228939344472
